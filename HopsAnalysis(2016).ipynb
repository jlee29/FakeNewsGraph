# %%
# %matplotlib inline
import csv
from datetime import datetime
from urlparse import urlparse
import json
import snap

# %%
def extractDomain(rawURL):
	parsedUrl = urlparse(rawURL)
	if parsedUrl.netloc.startswith('www.'):
		return parsedUrl.netloc[4:]
	return parsedUrl.netloc

def isUninteresting(url):
    if 'facebook' in url:
        return True
    elif 'instagram' in url:
        return True
    elif 'twitter' in url:
        return True
    elif 'google' in url:
        return True
    elif 'youtube' in url:
        return True
    elif url == 'https://t.co/':
        return True
    elif 'bit.ly' in url:
        return True
    else:
        return False

# %%
LinkGraph = snap.TNGraph.New()

currID = 0
domainToNodeID = {}
IDtoDomain = {}
DomainCounts = {}
years = {}
months = {}

progress = 0

for i in [1, 2, 3, 5]: 
    min_date = -1
    max_date = -1
    with open("web-2016-09-links-clean-{}.txt".format(i)) as tsvfile:
        linkReader = csv.reader(tsvfile, delimiter='\t')
        for row in linkReader:
            fromDomain = extractDomain(row[0])
            
            if isUninteresting(fromDomain):
            	continue
            if fromDomain not in domainToNodeID:
            	domainToNodeID[fromDomain] = currID
                IDtoDomain[currID] = fromDomain
            	LinkGraph.AddNode(currID)
            	currID += 1

            uniqueToDomains = set()

            for link in row[2:]:
                try:
                    toDomain = extractDomain(link)
                    
                    if isUninteresting(toDomain):
                        continue
                    if toDomain not in DomainCounts: 
                        DomainCounts[toDomain] = 1
                    else:
                        DomainCounts[toDomain] += 1
                        
                    if toDomain not in domainToNodeID:
                        IDtoDomain[currID] = toDomain
                        domainToNodeID[toDomain] = currID
                        LinkGraph.AddNode(currID)
                        currID += 1
                    if toDomain not in uniqueToDomains:
                        LinkGraph.AddEdge(domainToNodeID[fromDomain],domainToNodeID[toDomain])
                        uniqueToDomains.add(toDomain)
                except ValueError:
                    pass

# %%
DomainCounts
# Out:
# {'http://s5m14.seesaa.net/': 2,
#  'http://toscanoirriverente.tumblr.com/': 3,
#  'http://www.bexhillobserver.net/': 37,
#  'http://starcancer.tumblr.com/': 2,
#  'http://www.davenportfamily.com/': 9,
#  'http://www.ellos.fi/': 2,
#  'http://photoboothz.wikia.com/': 1,
#  'http://www.wildstar-central.com/': 3,
#  'http://www.jacarebanguela.com.br/': 12,
#  'http://papum-pare.classi4u.com/': 1,
#  'http://www.EarthChanges.org/': 14,
#  'http://www.comune.roma.it/': 6,
#  'http://www.houseweb.com.tw/': 21,
#  'http://artozinos.blogspot.com/': 1,
#  'http://wirralglobe.co.uk/': 305,
#  'https://www.hbbtv.org/': 2,
#  'http://academy.hubspot.com/': 1,
#  'http://www.ministryofsound.com/': 8,
#  'http://notorious-yung-sushi.tumblr.com/': 2,
#  'http://kovastudios.com/': 2,
#  'http://bonryo.blog6.fc2.com/': 4,
#  'http://www.josemarti.cu/': 1,
#  'http://fortheloveoftech.com/': 5,
#  'http://mostlycajun.com/': 14,
#  'http://1.lifether.pay.clickbank.net/': 2,
#  'https://ida.stampinup.com/': 1,
#  'http://amaterials.exblog.jp/': 1,
#  'http://www.mulesoft.org/': 7,
#  'http://whitehouse.tumblr.com/': 13,
#  'http://www.manutti.com.br/': 2,
#  'http://cahorsvtt.over-blog.com/': 1,
#  'http://media3.marketwir/': 2,
#  'http://www.earlytindusters.com/': 1,
#  'https://www.carolinajournal.com/': 24,
#  'http://mediagallery.usatoday.com/': 20,
#  'http://www.iec.chdesc.IEC/': 784,
#  'http://www.phototopics.net/': 22,
#  'http://www.s-ge.com/': 1,
#  'http://codered.su/': 10,
#  'http://www.balch.com/': 2,
#  'http://juice.de/': 24,
#  'https://lahodod.blogspot.ro/': 2,
#  'http://wanderlustfulnesss.tumblr.com/': 2,
#  'http://kurdtoday.ir/': 2,
#  'http://uk.pinterest.com/': 3,
#  'http://........iends/': 1,
#  'http://www.healthable.org/': 58,
#  'http://www.clydewaterfront.com/': 2,
#  'http://pamswildroseblog.blogspot.com/': 14,
#  'http://odistritalao.blogspot.com/': 2,
#  'http://www.buncombe.k12.nc.us/': 2,
#  'http://www.spencerauthor.com/': 3,
#  'http://maxedtech.com/': 14,
#  'http://lowerfranz.tumblr.com/': 1,
#  'http://rumetzen.tumblr.com/': 1,
#  'http://www.computerworld.com.my/': 181,
#  'http://sabrenoise.com/': 2,
#  'http://sunmaimama39.blog.fc2.com/': 15,
#  'http://www.canalextremadura.es/': 4,
#  'http://www.thehypemagazine.com/': 4,
#  'http://rintsikkahihhuli.tumblr.com/': 2,
#  'https://www.rollingstone.com/': 5,
#  'http://www.economywatch.com/': 23,
#  'https://2014.twitter.com/': 4,
#  'https://ehjournal.biomedcentral.com/': 2,
#  'http://joanmiro.tumblr.com/': 2,
#  'http://victoriapinder.com/': 2,
#  'http://www.ldsces.org/': 4,
#  'https://www.omnimaga.org/': 12,
#  'http://lilmisssunshinee.tumblr.com/': 2,
#  'http://honoratofilgueiras19.blogspot.com/': 1,
#  'http://theoffendingadam.com/': 2,
#  'http://iphone7pro.blog.fc2.com/': 1,
#  'http://attitudelive.com/': 1,
#  'http://scourge565.blog.fc2.com/': 1,
#  'https://dynabook.com/': 1,
#  'http://between.wikia.com/': 1,
#  'http://news.detik.com/': 2960,
#  'http://www.yourcalifornia.org/': 2,
#  'http://www.Treetopia.com/': 2,
#  'http://www.auto-service.de/': 35,
#  'http://www.holcombeharriers.com/': 4,
#  'http://cocoinfo24.blog.fc2.com/': 1,
#  'https://www.viabtc.com/': 1,
#  'http://harunyahya.org/': 4,
#  'http://ktliterary.com/': 1,
#  'http://m6onsoftware.blogspot.com/': 2,
#  'http://tecnoartes.net/': 20,
#  'http://www.meteoportaleitalia.it/': 1,
#  'http://mapmaker.education.nationalgeographic.com/': 1,
#  'http://gilneo14.tumblr.com/': 2,
#  'http://www.pryzm.co.uk/': 2,
#  'https://irp.nih.gov/': 6,
#  'http://www.tenantmagic.net/': 6,
#  'http://amlwchmagor.blogspot.com/': 2,
#  'http://izmsy.tumblr.com/': 2,
#  'http://unitiperlasalute.blogspot.it/': 1,
#  'http://audiokarma.org/': 869,
#  'http://tesoridietruria.it/': 2,
#  'http://www.tfoa.eu/': 2,
#  'http://www.bdc-forum/': 2,
#  'http://247ureports.com/': 33,
#  'http://xsockets.net/': 2,
#  'http://www.financialbox.gr/': 2,
#  'http://northerntrash.tumblr.com/': 1,
#  'http://sinitai.tumblr.com/': 2,
#  'http://www.savingmyfamilymoney.com/': 382,
#  'https://assistance.orange.fr/': 4,
#  'http://www.websterpost.com/': 50,
#  'https://www.bestscheck.de/': 2,
#  'http://tikitail.tumblr.com/': 1,
#  'http://www.m-w.com/': 3,
#  'https://www.peoplespunditdaily.com/': 1,
#  'http://whiteorkid.se/': 3,
#  'http://www.palmereventscenter.com/': 1,
#  'http://thebestmidgardian.tumblr.com/': 4,
#  'http://u1bleath.blog.fc2.com/': 1,
#  'http://essay-company.com/': 1,
#  'http://ganbaremmc.exblog.jp/': 1,
#  'http://foreseethefuture.seesaa.net/': 2,
#  'http://7ayaskya.tumblr.com/': 2,
#  'http://troye.si/': 52,
#  'http://tutitu.tv/': 26,
#  'http://othersurface.blogspot.ro/': 2,
#  'http://ocolly.com/': 5,
#  'https://www.stdcheck.com/': 1,
#  'http://nebulously-burnished.tumblr.com/': 2,
#  'http://www.hoteldelamere.com/': 1,
#  'http://www.color.rs/': 2,
#  'http://www.thefashionisto.com/': 84,
#  'http://www.uggbootsonsale.top/': 25,
#  'http://isasm.tumblr.com/': 24,
#  'http://koolebar.ir/': 1,
#  'http://rebelminis.blogspot.com/': 1,
#  'http://www.chicagosplash.com/': 3,
#  'http://www.20minutos.com.mx/': 5,
#  'http://www.civicyouth.org/': 2,
#  'http://kiryakirayad.blog.so-net.ne.jp/': 2,
#  'http://www.islamonline.net/': 2,
#  'http://www.fursadnepal.com/': 2,
#  'http://captain-samosa.tumblr.com/': 2,
#  'http://nhlifefree.com/': 8,
#  'http://corrieredirieti.corr.it/': 14,
#  'http://www2.tokai.or.jp/': 1,
#  'http://flamingnora.blogspot.com/': 3,
#  'http://mrsmiga.blogspot.com/': 1,
#  'http://www.nationsautoelectric.com/': 168,
#  'http://newcomertech.com/': 2,
#  'http://blog.istation.com/': 1,
#  'http://anttar.tumblr.com/': 2,
#  'http://www.indeed.com/': 7475,
#  'http://luminesque-cream.wikia.com/': 1,
#  'http://www.watransition.com.au/': 1,
#  'http://www.corker.senate.gov/': 8,
#  'http://www.emiratesairline.co.uk/': 1,
#  'http://www.democracyjournal.org/': 3,
#  'http://x2t.com/': 3,
#  'http://cohenandsteers.com/': 2,
#  'http://digital.vpr.net/': 552,
#  'http://www.sos.idaho.gov/': 5,
#  'https://planetprentonia.com/': 2,
#  'http://www.philbio.org/': 3,
#  'http://www.daywooddrive.com/': 3,
#  'http://lr-club.com/': 545,
#  'http://www.slayerment.com/': 1,
#  'http://hechizosdeamor.biz/': 2,
#  'http://nonkurumasuki.blog.so-net.ne.jp/': 3,
#  'http://www.neusoft.com/': 4,
#  'http://www.singulargreen.com/': 3,
#  'http://www.ascsracing.com/': 4,
#  'http://dev.compunics.com.ni/': 2,
#  'http://saint-christophe-sur-le-nais.com/': 1,
#  'http://metaphoricalmetamorphmagus.tumblr.com/': 3,
#  'http://www.tijdgeest.eu/': 1,
#  'http://www.paintscratch.com/': 46,
#  'http://www.dbb.de/': 1,
#  'http://cinesport.ajc.com/': 114,
#  'http://gsis.gr/': 1,
#  'http://www26.atwiki.jp/': 3,
#  'http://mamarni-kompleks.tumblr.com/': 2,
#  'http://a197.phobos.apple.com/': 1,
#  'http://movies.yahoo.com/': 3,
#  'http://www.theface.vn/': 40,
#  'http://www.kglsribr.com/': 2,
#  'http://www.pakbest.by\xd0\xa2\xd0\xb5\xd0\xbb\xd0\xb5\xd1\x84\xd0\xbe\xd0\xbd\xd1\x8b:/': 5,
#  'http://coraline.wikia.com/': 25,
#  'http://www.helaba.de/': 2,
#  'http://aiello-del-sabato.virgilio.it/': 3,
#  'http://blogs.tedneward.com/': 2,
#  'http://kolya.qaix.com/': 1,
#  'http://obkstm.tumblr.com/': 2,
#  'http://www.newmexico.org/': 3,
#  'http://www.rogue.com/': 1,
#  'http://www.saglikekibi.com/': 12,
#  'http://www.analpornvideos.xxx/': 8,
#  'http://gojifuta99.tumblr.com/': 2,
#  'https://bluejayblog.files.wordpress.com/': 4,
#  'http://notoriouslyjazz.tumblr.com/': 2,
#  'http://budgetlightforum.com/': 2,
#  'http://naked.dk/': 1,
#  'http://motorhomespecialistreviews.com/': 2,
#  'http://192.168.99.100:9000/': 1,
#  'http://opennebula.systems/': 1,
#  'http://kwmc.org.uk/': 1,
#  'http://slavery.virginia.edu/': 7,
#  'http://citizensfortrump.com/': 1,
#  'https://www.yetiairlines.com/': 93,
#  'http://www.malecha.org.ua/': 1005,
#  'http://www.coffsharbourbuskers.com/': 4,
#  'http://www.tugg.com/': 2,
#  'http://villeneuvedelaraho.blogs.lindependant.com/': 2,
#  'http://jinbowiki.org/': 2,
#  'http://william-brown.whirligigtv.yuku.com/': 1,
#  'http://blogs.msdn.com/': 15,
#  'http://eleniwins.tumblr.com/': 2,
#  'http://megurimegurunews.blog.fc2.com/': 68,
#  'http://asmcosplay.tumblr.com/': 1,
#  'http://www.avnet.com/': 10,
#  'http://carmelchoirs.org/': 1,
#  'http://www.cb-spain.es/': 2,
#  'https://sinema.house.gov/': 1,
#  'http://abchp.blogspot.com/': 4,
#  'http://www.englewoodfh.com/': 1,
#  'http://www.asef.org/': 2,
#  'http://mantegna1375.tumblr.com/': 4,
#  'http://cgi.ebay.com.au/': 6,
#  'http://www.newscionxb.com/': 9,
#  'http://www.centurylink.com.au/': 3,
#  'https://www.ketto.org/': 1,
#  'http://www.Relapse.com/': 6,
#  'http://investor.pandora.com/': 3,
#  'http://gaysexalltheway.tumblr.com/': 1,
#  'https://info.yahoo.com/': 415,
#  'http://www.cramasie.com/': 1,
#  'http://www.ferragamo-shoes.us.com/': 1,
#  'http://www.autohausaz.com/': 16,
#  'https://www.mindoula.com/': 2,
#  'https://howdrinkingsavedmylife.wordpress.com/': 2,
#  'http://www.sacd.fr/': 1,
#  'http://black11829.blog.fc2.com/': 1,
#  'http://reggaerecall2010.blogspot.com/': 2,
#  'http://www.mobivox.com/': 1,
#  'http://ietne.livejournal.com/': 2,
#  'http://www.anglicannews.org/': 7,
#  'http://jeannaapples.tumblr.com/': 2,
#  'http://fivesixteenmedia.com/': 1,
#  'http://www.ebrd.com/': 9,
#  'http://www.addcotedopale.fr/': 2,
#  'http://globovision.com/': 15,
#  'http://insanityistrash.tumblr.com/': 1,
#  'http://manoramaonline.com/': 6,
#  'http://eset.com/': 2,
#  'http://www.findyourslash.com/': 1,
#  'http://www.aussiestockforums.com/': 6,
#  'http://www.gobiquity.com/': 22,
#  'http://bybeti.wordpress.com/': 4,
#  'https://anothercyclist.wordpress.com/': 3,
#  'http://cholonsaigon.vn/': 1,
#  'http://docs.alfresco.com/': 1,
#  'http://tasnimnews.com/': 14,
#  'http://frumil9l4.forumcircle.com/': 1,
#  'https://kopitiambot.com/': 812,
#  'https://www.criterion.com/': 4,
#  'http://www.youngwomenstrust.org/': 3,
#  'http://www.naoesuzuki.com/': 1,
#  'http://owl.li/': 10,
#  'http://An%20Orthodox%20synagogue%20in%20New%20Jersey%20has%20hired%20Lila%20Kagedan,%20the%20first%20Yeshivat%20Maharat%20graduate%20to%20go%20by%20the%20title%20%E2%80%9Crabbi.%E2%80%9D%20Mount%20Freedom%20Jewish%20Center,%20in%20Randolph,%20New%20Jersey,%20announced%20in%20a%20news%20release%20Monday%20that%20Kagedan%20is%20joining%20its%20%E2%80%9Cspiritual%20leadership%20team.%E2%80%9D%20The%20news%20release%20did%20not%20use%20the%20word%20%E2%80%9Crabbi,%E2%80%9D%20instead%20referring%20to%20Kagedan%20as%20a%20%E2%80%9CYeshivat%20Maharat%20graduate.%E2%80%9D%20Kagedan,%20a%20native%20of%20Canada,%20was%20ordained%20in%20June%20by%20the%20New%20York-based%20seminary%20training%20Orthodox%20female%20clergy.%20Most%20graduates%20there%20have%20eschewed%20the%20title%20rabbi,%20opting%20instead%20for%20%E2%80%9Cmaharat%E2%80%9D%20or%20%E2%80%9Crabba.%E2%80%9D%20Kagedan%20announced%20at%20a%20Jewish%20conference%20in%20December%20that%20she%20had%20accepted%20a%20job%20with%20an%20Orthodox%20American%20synagogue%20but%20declined%20to%20identify%20it.%20BREAKING%20NEWS%20Arthur%20Obermayer,%20US%20philanthropist%20who%20preserved%20German-Jewish%20history,%20dies%20at%2084%20Report:%20660,000%20Jewish-Israelis%20can%E2%80%99t%20legally%20marry%20in%20Israel%20Book%20on%208-year-old%20Warsaw%20Ghetto%20boy%20wins%20Jewish%20literature%20medal%20READ:%20New%20cohort%20of%20clergy%20tests%20Orthodox%20readiness%20for%20women%20rabbis%20Mount%20Freedom%20Jewish%20Center%20describes%20itself%20on%20its%20website%20as%20%E2%80%9Copen%20orthodox,%E2%80%9D%20a%20nascent%20movement%20in%20modern%20Orthodoxy%20that%20believes%20in%20greater%20religious%20leadership%20roles%20for%20women,%20among%20other%20things.%20According%20to%20the%20synagogue%E2%80%99s%20news%20release,%20Kagedan%E2%80%99s%20responsibilities%20will%20be%20%E2%80%9Cto%20teach%20Torah,%20encourage%20greater%20love%20and%20celebration%20of%20mitzvoth%20and%20to%20provide%20learning%20opportunities%20for%20adults%20and%20children,%20connect%20with%20young%20families%20in%20and%20around%20the%20community%20and%20participate%20in%20lifecycle%20and%20pastoral%20needs%20alongside%20Rabbi%20Menashe%20East.%E2%80%9D%20As%20of%20June,%20Yeshivat%20Maharat%20has%20ordained%2011%20st/': 1,
#  'http://www.barefootrunning.fas.harvard.edu/': 1,
#  'http://www.zeeuwseconnectie.nl/': 1,
#  'http://maptell.com/': 3,
#  'http://www.tiogapublishing.com/': 2,
#  'https://www.jimin.jp/': 2,
#  'http://www.shartimusprime.net/': 14,
#  'https://toolkit.mozilla.org/': 2,
#  'https://calendly.com/': 2,
#  'http://www.ukiahdailyjournal.com/': 1,
#  'http://www.foals.co.uk/': 2,
#  'https://thornburgthoughts.wordpress.com/': 2,
#  'http://markets.smh.com.au/': 400,
#  'https://anaddictsscrapbook.com/': 1,
#  'http://www.leroyalmeridienabudhabi.com/': 1,
#  'http://hotwomenmeninbikinilingeriethong.tumblr.com/': 1,
#  'http://www.timesleader.com/': 10,
#  'http://www.newsboost.com/': 1,
#  'http://www.vanguardnewsnetwork.com/': 68,
#  'http://blog.epa.gov/': 2,
#  'http://www.raceforiran.com/': 1,
#  'http://feedback.scoop.it/': 6,
#  'http://bananana-crepes.tumblr.com/': 2,
#  'http://www.glenbradford.com/': 2,
#  'https://jordim.wordpress.com/': 1,
#  'http://albertovieira.net/': 1,
#  'http://the-eleventh-consulting-impala.tumblr.com/': 2,
#  'http://zxrrkntn.blog.so-net.ne.jp/': 2,
#  'http://lofipoca.pe.hu/': 46,
#  'http://collaboratori.ilcittadino.it/': 1,
#  'http://juvenilia.tumblr.com/': 5,
#  'http://es.yunque.wikia.com/': 2,
#  'http://www.cagepotato.com/': 9,
#  'http://ritke.vuodatus.net/': 2,
#  'http://www.jaycar.com.au/': 1,
#  'http://suretalent.blogspot.com/': 2,
#  'http://marinafontaine.blogspot.com/': 2,
#  'https://www.inspq.qc.ca/': 1,
#  'http://www.europac.com/': 3,
#  'http://www.ilsoftware.it/': 658,
#  'http://www.jamaicans.com/': 1,
#  'http://tvtuner.co/': 2,
#  'http://silentium-et-dolore.tumblr.com/': 1,
#  'http://awin.aviationweek.com/': 36,
#  'http://www.cigarinspector.com/': 45,
#  'http://mobdisc.com/': 8,
#  'http://jgc.blog.jp/': 17,
#  'http://www.escadadoceu.org/': 1,
#  'http://stjoesworkshop.com/': 1,
#  'http://www.inquilab.com/': 1,
#  'http://www.hcsafety.com/': 6,
#  'http://www.aytoleon.es/': 1,
#  'http://familyspice.com/': 1,
#  'https://unoccupyabq.org/': 1,
#  'http://SECCountry.com/': 2,
#  'http://canopycanopycanopy.com/': 2,
#  'http://turcl.tumblr.com/': 2,
#  'http://wakeweekly.com/': 2,
#  'http://promotions.newegg.com/': 1,
#  'http://shinseikiunion.blog104.fc2.com/': 3,
#  'http://www.mcdonaldfunerals.com/': 2,
#  'http://www.magvilla.nl/': 1,
#  'http://www.bourbonblog.com/': 3,
#  'http://www.roushperformance.com/': 3,
#  'http://obs.monde.juif.free.fr/': 1,
#  'http://mikeacastle.tumblr.com/': 2,
#  'http://humblyproud.tumblr.com/': 1,
#  'http://floridatoday.com/': 1363,
#  'http://nykoping-stad.annonsera.se/': 1,
#  'http://2hikkosi.blog.so-net.ne.jp/': 3,
#  'http://vintagehalloweencollector.blogspot.com"/': 3,
#  'http://elitedai.ly/': 18,
#  'http://fkutaman.ru/': 5,
#  'http://www.ostrovets.by/': 1,
#  'https://www.graymalin.com/': 1,
#  'http://www.odloty.pl...dia/': 1,
#  'http://kuboji.tumblr.com/': 2,
#  'https://cc.callinfo.com/': 1,
#  'http://shoeslatest.com/': 6,
#  'http://livingsocial.com/': 37,
#  'http://www.nailsmag.com/': 79,
#  'http://bicesteradvertiser.net/': 602,
#  'http://www.tepco.co.jp/': 105,
#  'http://slovenskapolitika.sulik.sk/': 2,
#  'http://sibilla-gr-sibilla.blogspot.de/': 1,
#  'http://keiba74.blog12.fc2.com/': 1,
#  'http://www.rightwingwatch.org/': 2335,
#  'http://www.9literfilmy.pl/': 6,
#  'http://www.vistaprint.it/': 1,
#  'http://regforum.ru/': 17,
#  'http://echopress.com/': 67,
#  'http://documentedthefilm.com/': 1,
#  'https://contactus.target.com/': 2,
#  'http://www.portal25horas.com.br/': 107,
#  'http://yanotch.blog94.fc2.com/': 1,
#  'https://www.ozbargain.com.au/': 3690,
#  'http://www.zdnet.com/': 4372,
#  'http://www.intuitionbyperspective.com/': 1,
#  'http://ww2.frost.com/': 15,
#  'http://jobboarders.com/': 2,
#  'http://www.10000nen.com/': 2,
#  'http://lite-ra.com/': 16,
#  'http://chibi8go.exblog.jp/': 3,
#  'http://ciaovecio64.altervista.org/': 1,
#  'http://www.c8sciencepanel.org/': 5,
#  'http://www.chu-toulouse.fr/': 2,
#  'http://xn--hdks269ujsd3nn5wif51d.xyz/': 1,
#  'http://mo-choi.tumblr.com/': 2,
#  'http://www.natuurpuntzevenbergenbos.co.nf/': 2,
#  'http://www.vegamot.no/': 2,
#  'https://ginny0.wordpress.com/': 6,
#  'http://www.precisiondiscovery.com/': 1,
#  'http://www.ethernet-powerlink.org/': 3,
#  'http://www.sportmag.fr/': 2,
#  'http://sororitynoise.tumblr.com/': 1,
#  'http://galwaycrystal.ie/': 8,
#  'https://www.onetonline.org/': 2,
#  'http://mortise01.wikia.com/': 1,
#  'http://server.rmnrelax.de/': 6,
#  'https://lynnemthomas.com/': 2,
#  'http://www.braunbuffel.com/': 1,
#  'http://www.bubbagump.com/': 1,
#  'http://i-donline.tumblr.com/': 8,
#  'https://dorkenstein.wordpress.com/': 3,
#  'http://sabraesquedesigns.wordpress.com/': 1,
#  'https://www.Send2Press.com/': 2,
#  'http://www.viaemilianet.it/': 2,
#  'http://s1.lemde.fr/': 28,
#  'http://www.ge2ch.net/': 16,
#  'http://www.swtor2credits.com/': 12,
#  'http://mavangvn.vn/': 2,
#  'http://launchpad.octaneoc.org/': 1,
#  'http://minamikatabijinya.blog.fc2.com/': 1,
#  'https://bmwmoa.org/': 24,
#  'http://www.one.de/': 6,
#  'http://www.danubeflats.at/': 3,
#  'http://www.bass-strings.com/': 1,
#  'http://www.commercial-news.com/': 15,
#  'http://www.elvis.com/': 6,
#  'http://ontheredcarpet.com/': 679,
#  'http://www.biblicalwomanhoodonline.com/': 15,
#  'http://www.thirdrockventures.com/': 11,
#  'http://sankei.jp.msn.com/': 7,
#  'http://go-chris-us.tumblr.com/': 2,
#  'http://judy777.blog.fc2.com/': 1,
#  'https://christophercantwell.com/': 6,
#  'http://jamiekinosian.tumblr.com/': 4,
#  'http://www.fotbolldirekt.se/': 31,
#  'http://www.sundayguardianlive.com/': 3,
#  'http://m.yzwb.net/': 1,
#  'http://www.characterspub.com/': 1,
#  'http://www.hoteldeparis-sainttropez.com/': 2,
#  'http://editorial%20opportunities/': 1,
#  'http://wasatchcrossfit.com/': 12,
#  'http://1mrtm.com/': 2,
#  'http://sexshop-barcelona.com.es/': 1,
#  'http://www.megabuilders.com/': 1,
#  'http://sydney.edu.au/': 83,
#  'http://anno.onb.ac.at/': 36,
#  'http://www.carricktoday.co.uk/': 1,
#  'http://playerbok5.blog129.fc2.com/': 1,
#  'http://rolliks.com.ua/': 1,
#  'http://www.cfcindia.com/': 10,
#  'http://www.skyfoto.com.br/': 10,
#  'http://looki.uol.ua/': 2,
#  'http://idxchat.blog.fc2.com/': 1,
#  'https://solutions.oracle.com/': 1,
#  'https://www.vps.ag/': 6,
#  'http://AnimalLearningSystems.com/': 4,
#  'http://yakanphoto.exblog.jp/': 3,
#  'http://www.cinemacon.com/': 1,
#  'https://dornsife.usc.edu/': 2,
#  'http://www.klack.de/': 27,
#  'http://inuzure.exblog.jp/': 16,
#  'http://www.michaelkorsoutletcanada.in.net/': 1,
#  'http://nickwaterhouse.com/': 1,
#  'http://joelschat.com/': 2,
#  'http://shouwa.memo.wiki/': 2,
#  'http://m.essentialbaby.com.au/': 80,
#  'http://www.driftsurfing.eu/': 1,
#  'http://budapestbyblimp.blogspot.ro/': 1,
#  'http://edworkforce.house.gov/': 6,
#  'http://www.beatthegmat.com/': 17,
#  'http://www.marvistavet.com/': 1,
#  'http://www.oxfordfinance.co.nz/': 60,
#  'http://www.zubeidamustafa.com/': 2,
#  'http://gold.t-online.de/': 6,
#  'https://goofbag.com/': 10,
#  'http://ettrottmonogram.blogspot.com.br/': 1,
#  'http://loungekyma.blog.fc2.com/': 2,
#  'http://faktor.hu/': 79,
#  'https://elisaviihde.fi/': 9,
#  'http://pixelsgt.blogspot.com/': 3,
#  'http://www.boxeomundial.com/': 56,
#  'http://bestroadmaintenancemachinery.com/': 1,
#  'http://econsultancy.com/': 1,
#  'http://www.be-street.com/': 83,
#  'http://www.savings-on-hotels.com/': 1,
#  'http://www.thakoon.com/': 2,
#  'http://www.sac-cas.ch/': 1,
#  'https://www.workitdaily.com/': 10,
#  'https://www.lifeline.org.au/': 25,
#  'http://cubedhost.com/': 65,
#  'http://amiedeckerbeauty.com/': 2,
#  'http://industrie40.oesterreich.ahk.de/': 2,
#  'http://wmky.org/': 77,
#  'http://haute-ah.tumblr.com/': 1,
#  'http://www.lynntaylor.com/': 1,
#  'http://cocolog.kaiketsu.nifty.com/': 1,
#  'http://dynamicsgpland.blogspot.com/': 3,
#  'http://vod.fjdh.com/': 1,
#  'http://www.zhibeifw.com/': 4,
#  'http://spiritcloth.typepad.com/': 3,
#  'http://camdamage.tumblr.com/': 3,
#  'http://alumni.illinoisstate.edu/': 1,
#  'http://www.djcline.com/': 2,
#  'http://sevilla.abc.es/': 4763,
#  'http://www.scvotes.org/': 8,
#  'http://www.abideabove.com/': 1,
#  'http://www.h-p-w.com/': 1,
#  'https://www.gfinity.net/': 1,
#  'http://tibet.net/': 26,
#  'http://www.explorekirkland.com/': 2,
#  'http://ccensor.tumblr.com/': 1,
#  'https://listermarketing.activehosted.com/': 1,
#  'http://kaxtrem.tumblr.com/': 2,
#  'http://um-caminhar.blogspot.com/': 1,
#  'https://beniciapaw.wordpress.com/': 1,
#  'https://originalimaginings.wordpress.com/': 1,
#  'http://cavett.blogs.nytimes.com/': 90,
#  'http://img191.imageshack.us/': 1,
#  'http://nikkan-spa.jp/': 107,
#  'http://www.derbund.ch/': 51,
#  'http://www.ecuworx.co.uk/': 6,
#  'http://forum.korrigansonline.com/': 1,
#  'http://www.sfml-dev.org/': 2,
#  'http://parajetunero.blogspot.ro/': 3,
#  'http://kind-hufflepuff.tumblr.com/': 2,
#  'http://realm-of-lead-addiction.blogspot.com/': 1,
#  'http://groovejamgreensboro.com/': 1,
#  'http://marshallparthenon.com/': 13,
#  'http://medicalnews.gr/': 1,
#  'http://www.createasmilestamps.com/': 2,
#  'http://radiovolna.net/': 1,
#  'http://www.fashionedits.com/': 12,
#  'http://sharing.mayoclinic.org/': 2,
#  'http://apipb.com.br/': 1,
#  'http://afrikanblackcoalition.org/': 10,
#  'http://namebadges.wikia.com/': 1,
#  'http://beno.org.uk/': 2,
#  'http://money.oe24.at/': 22,
#  'https://yakan-hiko.com/': 1,
#  'https://washekoda.com/': 1,
#  'http://www.communiquepr.com/': 15,
#  'http://www.civilopedia.info/': 1,
#  'http://talliara.tumblr.com/': 2,
#  'http://z.blogads.com/': 42,
#  'http://cats-blog.com/': 9,
#  'http://www.baurum.ru/': 2,
#  'http://ffhobby.exblog.jp/': 4,
#  'http://whoosnap.com/': 1,
#  'http://orangetreelane.com/': 2,
#  'http://www.anglicanjournal.com/': 2,
#  'http://locallansdowne.com/': 28,
#  'http://usworker.coop/': 2,
#  'http://nicesideburns.tumblr.com/': 2,
#  'http://img59.imageshack.us/': 6,
#  'http://alhudacibe.blogspot.ro/': 1,
#  'http://slowfoot.pl/': 1,
#  'http://www.thetowntalk.com/': 64,
#  'http://www.cmo.com.au/': 6,
#  'http://worldalzmonth.org/': 1,
#  'http://alzheimersaustraliaactbusinessbreakfast.eventbrite.com.au/': 14,
#  'http://xzsrkaxucnepibtqehic.blog.so-net.ne.jp/': 2,
#  'http://archive.fast-edgar.com/': 97,
#  'http://www.hsn.com/': 55,
#  'http://www.yaroslavova.ru/': 5,
#  'http://muriyari4545.blog.fc2.com/': 1,
#  'http://bc01.rp-online.de/': 2,
#  'http://thefeministwire.com/': 13,
#  'http://m.mentalfloss.com/': 1,
#  'http://www.boatdesign.net/': 8,
#  'http://momo.com/': 1,
#  'http://saimon4211.blog.fc2.com/': 3,
#  'http://kakehasi-iwaoki.cocolog-nifty.com/': 2,
#  'http://hawaii.gov/': 3,
#  'http://writetheworld.com/': 12,
#  'http://satanrat.tumblr.com/': 2,
#  'http://akb48channel.ldblog.jp/': 5,
#  'http://www.l6sbc.ca/': 16,
#  'http://www.ccoocx.com/': 2,
#  'https://untamedtrail.wordpress.com/': 2,
#  'http://lzymskn.tumblr.com/': 2,
#  'http://www.puliamoilmondo.it./': 2,
#  'http://www.top5th.co.in/': 1,
#  'http://k87i6dus.blog.fc2.com/': 1,
#  'http://www.magic-237.com/': 1,
#  'http://itsraininginsidemyheart.tumblr.com/': 1,
#  'http://android-developers.blogspot.mx/': 1,
#  'http://ireland.global-free-classified-ads.com/': 5,
#  'http://Statigr.am/': 1,
#  'http://www.motorpage.ru/': 27,
#  'http://www.slponline.com/': 6,
#  'https://plus.dagensjuridik.se/': 4,
#  'http://www.sauditimes.com/': 2,
#  'http://www.bane.dk/': 7,
#  'http://www.brandcent...=user&id=156670/': 1,
#  'http://www.photosight.org/': 1,
#  'http://dbedt.hawaii.gov/': 2,
#  'http://www.a4mods.com/': 1,
#  'http://gloria.tv/': 4,
#  'http://files.giveawayoftheday.com/': 3,
#  'http://mtdb.com/': 132,
#  'http://monokultur.dk/': 1,
#  'http://www.garxfire.com/': 4,
#  'http://www.uhu.com/': 1,
#  'http://sportspagemagazine.com/': 71,
#  'http://www.otraeducacion.es/': 1,
#  'https://theworldofhanbel.com/': 2,
#  'http://translate.google.com/': 235,
#  'http://tlsfv.de/': 4,
#  'http://www.gazellebeatboxschool.com/': 10,
#  'https://act.notwhoweare.us/': 2,
#  'http://beginagainfilm.com/': 1,
#  'http://www.clearcreekstrategies.com/': 5,
#  'http://www.mpp.org/': 3,
#  'http://www.centerparcs.co.uk/': 9,
#  'http://www.peiwei.com/': 3,
#  'http://blogs.gartner.com/': 46,
#  'http://blog-imgs-84.fc2.com/': 1,
#  'http://velocipedistes.com/': 4,
#  'http://gippslandtimes.com.au/': 156,
#  'http://www.alwaysunderpay.com/': 4,
#  'https://www.risknet.de/': 2,
#  'http://us-campaign-committees.insidegov.com/': 1,
#  'http://www.inside-it.ch/': 8,
#  'http://www.axa-winterthur.ch/': 3,
#  'http://thingswewontremember.tumblr.com/': 1,
#  'http://www.romanoprodi.it/': 13,
#  'http://www.autoaktuell.at/': 13,
#  'http://piptwits.com/': 16,
#  'http://www.riverstourtrust.org/': 16,
#  'http://slnewserdesign.blogspot.com/': 1,
#  'http://wjsp.drupal.publicbroadcasting.net/': 2,
#  'http://instagramgirlz.tumblr.com/': 1,
#  'http://www.derekpacifico.com/': 1,
#  'http://featherygold.livejournal.com/': 5,
#  'http://ilcorsaronero.info/': 6,
#  'http://morinonakiusagi1006.blog.fc2.com/': 1,
#  'http://marvelspelltemple.webs.com/': 1,
#  'http://wheels.theadvocate.com/': 5,
#  'http://traihaideoic.blog.fc2.com/': 2,
#  'https://www.farmheroesvsmonsanto.com/': 1,
#  'https://www.moduslink.com/': 1,
#  'http://www.tamsoldracecarsite.net/': 24,
#  'http://mybigtitsbabes.com/': 44,
#  'http://dms.ntsb.gov/': 1,
#  'http://heyb1tch.tumblr.com/': 2,
#  'https://mylmuconnect.blackboard.com/': 3,
#  'http://wwwaporrito.blogspot.com/': 14,
#  'http://www.mouseowners.com/': 90,
#  'http://handsonexperiencexxx.tumblr.com/': 1,
#  'http://americanfinancesolutions.com/': 1,
#  'http://187.45.185.174/': 1,
#  'http://www.blogsbypatsy.com/': 3,
#  'http://www.mrslondonsbakery.com/': 1,
#  'http://bigboobbasement.tumblr.com/': 2,
#  'http://sberbankins.ru/': 10,
#  'http://www.avert.org/': 54,
#  'http://greenwichindustrialhistory.blogspot.com/': 2,
#  'http://stanbury.org/': 2,
#  'http://newbelgium.com/': 1,
#  'http://www.cibovino.com/': 7,
#  'http://marcolotto.forumcommunity.net/': 1,
#  'http://www.thejewelleryeditor.com/': 15,
#  'https://www.viamichelin.es/': 2,
#  'http://niyata2807.tumblr.com/': 4,
#  'http://thirdage.com/': 10,
#  'http://\xe2\x80\x8bwebmontag-schwerin.de/': 2,
#  'http://unipi.technology/': 4,
#  'http://kotoritai.blog.fc2.com/': 1,
#  'http://hight3ch.com/': 26,
#  'http://www.pressebox.de/': 91,
#  'http://www.mariner-sails.com/': 4,
#  'http://FEREDAYHEATING.COM/': 3,
#  'http://luckeeyy.tumblr.com/': 2,
#  'http://mullenmullen8.blog.fc2.com/': 1,
#  'http://darkwaltz25.tumblr.com/': 2,
#  'https://www.catchoftheday.com.au/': 12,
#  'http://bfi.org/': 2,
#  'http://www.mercedes-benz.co.uk/': 1,
#  'http://lionsroar.us7.list-manage.com/': 1,
#  'http://esmeedelrey.tumblr.com/': 2,
#  'http://georzitofilho.blogspot.com/': 2,
#  'https://subscribe.theadvertiser.com/': 16,
#  'http://www.innerarmour.com/': 2,
#  'http://preservationvirginia.org/': 1,
#  'http://herbalhome.blog.fc2.com/': 1,
#  'http://steamworkshopdownloader.com/': 3,
#  'https://www.congstar.de/': 13,
#  'http://www.coreyfeldman.net/': 4,
#  'http://trisomi9ptrisomi20p.blogspot.com/': 1,
#  'http://counterspin.blogspot.com/': 99,
#  'https://www2.computable.nl/': 2,
#  'http://arianne-c.tumblr.com/': 23,
#  'http://gacha.blog.jp/': 2,
#  'http://psywb.springeropen.com/': 2,
#  'http://tickets.interlochen.org/': 1,
#  'http://www.caillet-terre-cuite.com/': 4,
#  'http://hormel.com/': 2,
#  'http://serversupportforum.de/': 11,
#  'http://www.robbierivera.com/': 1,
#  'http://educational-mobile-apps-games.wikia.com/': 1,
#  'https://www.gazzar.ch/': 2,
#  'http://biztravel.fvw.de/': 10,
#  'http://theweathercontinues.blogspot.mx/': 2,
#  'http://glitteringmuffins.com/': 2,
#  'https://www.owlsnestrecovery.com/': 2,
#  'http://www.hardangerviddanett.no/': 1,
#  'http://news.church.ua/': 3,
#  'https://chipsycrispy.wordpress.com/': 15,
#  'http://hotrodenginetech.com/': 50,
#  'http://inmotiontech.kayako.com/': 1,
#  'http://www.liguria2000news.com/': 33,
#  'http://books.wwnorton.com/': 13,
#  'http://www.mmo-champion.com/': 1525,
#  'http://stil-bluete.net/': 4,
#  'http://www.maghreb.nl/': 7,
#  'http://www.droidnews.ru/': 4,
#  'https://www.tune.com/': 1,
#  'http://HowToChangeMyLife.org/': 2,
#  'https://ldsinsights.wordpress.com/': 3,
#  'http://cdcaruso.com/': 13,
#  'http://www.nigerianelitesforum.com/': 1,
#  'http://www.raptureforums.com/': 30,
#  'http://macbidouille.com/': 24,
#  'http://www.forexsignals.ae/': 1,
#  'http://yhmgynz782.blog.fc2.com/': 1,
#  'http://www.mein-pferd.de/': 2,
#  'http://berutubusi.exblog.jp/': 3,
#  'https://sexonadeathbed.tumblr.com/': 2,
#  'http://www.dockwalk.com/': 2,
#  'http://www.frenchbubbles.co.uk/': 1,
#  'http://lawstudentjobs.net/': 9,
#  'http://www.cvccworks.edu/': 1,
#  'http://www.lisa.gerda-henkel-stiftung.de/': 2,
#  'http://www.unlugarenmismundos.com/': 3,
#  'http://www.kickasspussypump.com/': 21,
#  'https://dna.ancestry.com/': 17,
#  'http://www.radiobronglais.co.uk/': 68,
#  'http://readingismysuperpower.org/': 1,
#  'https://neharustagiblog.wordpress.com/': 2,
#  'http://pandklcga.blogspot.ro/': 1,
#  'https://pineconeswife.wordpress.com/': 1,
#  'http://hayasaka520.blog.fc2.com/': 1,
#  'http://www.gametracker.com/': 13,
#  'http://www.agencemediapalestine.fr/': 4,
#  'http://umno-tech.com/': 1,
#  'https://connect.ncdot.gov/': 2,
#  'http://www.icyousee.org/': 14,
#  'http://wilfullyobscure.blogspot.com/': 4,
#  'http://www.mundodastribos.com/': 71,
#  'http://billypenn.com/': 15,
#  'http://deadgirls.tumblr.com/': 19,
#  'http://www.123votez.com/': 1,
#  'http://geojobs.biz/': 39,
#  'http://Transparensee.com/': 3,
#  'http://dmmsirotoferadoga.blog.fc2.com/': 3,
#  'http://www.lincenergysystems.com/': 1,
#  'http://printeccomunicacao.com.br/': 1,
#  'http://www.mcn.com.au/': 4,
#  'http://sarcasticblogger.tumblr.com/': 70,
#  'http://nwamotherlode.com/': 18,
#  'http://www.jabra.co.uk/': 3,
#  'http://www.svlfreenews.com/': 1,
#  'https://upnorthreader.com/': 2,
#  'http://www.columbia.com/': 6,
#  'https://www.ibdb.com/': 26,
#  'http://elcamion.co.uk/': 1,
#  'http://sok-granatovy.livejournal.com/': 4,
#  'http://boysilk.tumblr.com/': 7,
#  'http://ratelobby.com/': 18,
#  'http://www.stiletto.uk.com/': 2,
#  'http://aliyahmassage.com/': 1,
#  'https://duartenuno.wordpress.com/': 1,
#  'http://jinnyboytv.bigcartel.com/': 1,
#  'http://classified.apartment-penang.com/': 2,
#  'https://trip-magazine.com/': 1,
#  'https://actionmapdepot.com/': 1,
#  'http://n.yam.com/': 48,
#  'http://x-pkr.blogspot.com/': 1,
#  'http://oidaex.exblog.jp/': 2,
#  'http://www.dredgingtoday.com/': 11,
#  'http://www.cansastre.com/': 1,
#  'http://lunar.colorado.edu/': 2,
#  'http://ellimaria.tumblr.com/': 1,
#  'http://www.bikepgh.org/': 10,
#  'http://www.tokyo-np.co.jp/': 104,
#  'http://www.oldtimertrend.com/': 3,
#  'http://www.yakuji.co.jp/': 6,
#  'http://au.ign.com/': 2,
#  'http://voidlauncherforums.voidswrath.com/': 8,
#  'http://gabrieltraveler.com/': 110,
#  'http://wdwdailynews.com/': 3,
#  'http://tallimalvezzi.tumblr.com/': 2,
#  'https://fastpokemap.se/': 3,
#  'http://www.windsor-taxis.com/': 2,
#  'http://www.vijesti.rtl.hr/': 619,
#  'http://somem.org/': 2,
#  'https://serratobabydiaries.wordpress.com/': 4,
#  'https://myboxeduniverse.wordpress.com/': 1,
#  'http://dont-call-me-camcam.tumblr.com/': 2,
#  'http://www.betmultimedia.it/': 6,
#  'http://retrofatale.livejournal.com/': 1,
#  'https://www.nvwa.nl/': 2,
#  'http://rakashaz.blogspot.com/': 1,
#  'http://papertripp.blogspot.com/': 2,
#  'http://www.carlocksmithsandiegoca.com">/': 1,
#  'http://h10010.www1.hp.com/': 6,
#  'http://www.truthout.org/': 59,
#  'http://tabhunterconfidential.com/': 1,
#  'http://SAPPHIREMINE.COM/': 8,
#  'http://d-duc.tumblr.com/': 4,
#  'http://kiyctc.com.kp/': 2,
#  'http://ohmlesspedals.com/': 2,
#  'http://lumiasan.tumblr.com/': 2,
#  'http://www.hochzeit.com/': 1,
#  'http://flack-o.tumblr.com/': 4,
#  'http://eschnou.com/': 1,
#  'http://www.medexsupply.com/': 4,
#  'http://www.ohchr.org/': 110,
#  'http://www.makeup.com/': 10,
#  'http://harrytsopanos.blogspot.com/': 6,
#  'http://cn.nytimes.com/': 10,
#  'https://service.piratenpartei-nrw.de/': 2,
#  'https://theunchained.net/': 1,
#  'http://cinemacineum.blogspot.com/': 1,
#  'http://natashaskitchen.com/': 13,
#  'http://www.droitsdeslyceens.com/': 6,
#  'http://miiiiio.exblog.jp/': 2,
#  'http://yle.fi/': 1548,
#  'http://f1rst-blood.blogspot.com/': 1,
#  'http://yosoytunombre.tumblr.com/': 4,
#  'http://misguiding.tumblr.com/': 2,
#  'http://xn--vckg5a9gugq39rhlyc.net/': 10,
#  'http://www.kostenlose-pr.eu/': 18,
#  'http://napoli.repubblica.it/': 103,
#  'http://www.hil.gov.in/': 1,
#  'http://austinheritagefestival.org/': 1,
#  'http://www.haycosasmuynuestras.com/': 2,
#  'http://www.tppmexico.org/': 4,
#  'http://tokusimakakutasu.blog.fc2.com/': 11,
#  'http://tungkaranhati.blogspot.com/': 43,
#  'http://quiet-peacee.tumblr.com/': 2,
#  'http://machinesforwar.blogspot.com/': 1,
#  'http://jgpaiva.dcmembers.com/': 1,
#  'http://www.oakleysunglassesebay.us.com/': 1,
#  'http://www.ericclapton.com/': 2,
#  'http://everybodysdummy.blogspot.com/': 3,
#  'http://www.lorraineaucoeur.com/': 1,
#  'http://oxfordtimes.co.uk/': 873,
#  'http://www.kenarnoldcsa.com/': 2,
#  'http://portaloaca.com/': 2,
#  'http://www.alfred.com/': 2,
#  'http://www.seattlepublictheater.org/': 4,
#  'https://www.sophiainstitute.com/': 2,
#  'http://victorymedia.com/': 4,
#  'http://www.solotravel.it/': 1,
#  'http://game-oldies.com/': 3,
#  'http://midnightsunak.com/': 6,
#  'http://quickchek.com/': 2,
#  'http://www.cloudyads.com/': 2,
#  'http://www.pacificgolf.co.jp/': 2,
#  'http://drymarchonic.tumblr.com/': 2,
#  'https://www.mediamiser.com/': 13,
#  'http://peperoncino100.blog.fc2.com/': 8,
#  'http://superlogblr.tumblr.com/': 5,
#  'http://saitokeiko.la.coocan.jp/': 1,
#  'http://member.naturalbirthandbabycare.com/': 1,
#  'http://www.trtspor.com/': 1,
#  'http://www.yeggi.com/': 2,
#  'http://www.tenis.net.pl/': 10,
#  'http://m.erosnow.com/': 46,
#  'http://www.senhhabitat.org/': 3,
#  'http://blogs.platts.com/': 35,
#  'https://reefs.com/': 4,
#  'https://supermariokrblog.wordpress.com/': 6,
#  'http://www.demandmedia.com/': 72,
#  'https://www.cubic.com/': 6,
#  'http://meteo.france3.fr/': 1,
#  'http://www.pandora.com.de/': 3,
#  'http://www.sport.fr/': 603,
#  'http://ratisaaa.tumblr.com/': 2,
#  'http://chuchu1222.exblog.jp/': 4,
#  'http://konkatsumagic.blog.so-net.ne.jp/': 1,
#  'https://about.bnef.com/': 5,
#  'http://www.oilandgastechnology.net/': 3,
#  'http://mariianadehoran.tumblr.com/': 1,
#  'http://mrschureads.blogspot.com/': 2,
#  'https://www.wbstraining.de/': 2,
#  'http://www.ce-eco.ratp.fr/': 4,
#  'https://www.sdopera.org/': 2,
#  'http://www.1sw1r.com/': 10,
#  'http://fightpunch.deviantart.com/': 1,
#  'http://christinebush.com/': 1,
#  'https://healthy.kaiserpermanente.org/': 2,
#  'https://scholarsphere.psu.edu/': 1,
#  'http://www.bilbaoakelarrehostel.com/': 2,
#  'http://www.musikfestspiele.com/': 1,
#  'http://planningreport.com/': 1,
#  'http://s1213.photobucket.com/': 9,
#  'http://www.enterpriseinnovation.net/': 11,
#  'http://www.wildflowerfashiontruck.com/': 1,
#  'http://www.smartdrive.net/': 2,
#  'http://www.willzuzak.ca/': 1,
#  'http://www.flvtube.net/': 1,
#  'https://localingua.wordpress.com/': 5,
#  'http://www.toonzone.net/': 439,
#  'http://www.meatinfo.ru/': 4,
#  'https://coenpeppelenbos.blogspot.nl/': 1,
#  'http://www.bakewithsonia.com/': 2,
#  'http://wondersofyunnan.com/': 4,
#  'http://asasame.blog.so-net.ne.jp/': 1,
#  'http://fauxskeleton.tumblr.com/': 2,
#  'http://www.curtislibrary.com/': 1,
#  'http://www.richardberg.net/': 2,
#  'http://arwendanish.blogspot.my/': 1,
#  'http://www.kanahomevideo.com/': 2,
#  'http://dangerousprototypes.com/': 10,
#  'https://assa.intertelecom.ua/': 2,
#  'http://www.regnum.ru/': 6,
#  'http://creditsweep.wikia.com/': 1,
#  'http://www.outlift.org/': 1,
#  'http://meteo.motorionline.com/': 1,
#  'http://www.esturirafi.com/': 2,
#  'http://utau.wikia.com/': 126,
#  'http://robertjackson.nationbuilder.com/': 3,
#  'http://tidd.ly/': 1834,
#  'http://independentmail.com/': 572,
#  'http://gregory-orr.wikia.com/': 1,
#  'http://www.pixelsandartdesign.com/': 2,
#  'http://www.michaelkorsoutlet-uk.me.uk/': 1,
#  'http://www.freeguestbook4you.de/': 2,
#  'http://prostir.museum/': 1,
#  'http://observatorio.escueladealimentacion.es/': 1,
#  'http://www.tvqc.com/': 2,
#  'http://haramastu.blog.so-net.ne.jp/': 1,
#  'http://theslrunway.blogspot.com/': 1,
#  'http://www.pistonspac.com/': 1,
#  'http://seattle.curbed.com/': 5,
#  'http://www.myjoyonline.com/': 2,
#  'http://stevendkrause.com/': 2,
#  'https://www.kendallj.com/': 11,
#  'http://www.tgvallesusa.it/': 1,
#  'http://factoriapoetica.blogspot.com/': 2,
#  'http://sixtyframes.blogspot.de/': 1,
#  'http://webzersolutions.in/': 11,
#  'http://gmail-help-desk-number.wikia.com/': 1,
#  'http://tushkan-blog.livejournal.com/': 3,
#  'http://bolvania.tumblr.com/': 2,
#  'http://ironmaiden.com/': 24,
#  'https://www.ftc.gov/': 115,
#  'http://ogamasa64.tumblr.com/': 1,
#  'http://zpravy.tiscali.cz/': 124,
#  'https://www.euractiv.com/': 53,
#  'http://ktcom.jp/': 2,
#  'http://www.brasilienportal.ch/': 2,
#  'http://investmentwatchblog.com/': 38,
#  'http://www.ezilidanto.com/': 1,
#  'http://run3page.com/': 1,
#  'http://www.ultracomms.com/': 3,
#  'http://www.cswlawllp.com/': 1,
#  'http://www.thewellsanantonio.com/': 1,
#  'http://hentaitk.blogspot.com/': 2,
#  'http://fergear.com/': 1,
#  'http://www.kernews.com/': 18,
#  'http://www.BodyTransformationTruth.com/': 2,
#  'http://www.ituenbasi.co.uk/': 4,
#  'https://www.google.co.uk/': 290,
#  'http://www.sjoey.com.tw/': 3,
#  'https://www.musicbed.com/': 6,
#  'http://miruca.tv/': 3,
#  'http://zukkermaedchen.de/': 15,
#  'http://www.pressreader.com/': 13,
#  'http://www.kodiakdailymirror.com/': 2,
#  'http://shoryuken.com/': 12,
#  'http://windowsitpro.com/': 58,
#  'https://harmonysama.tumblr.com/': 1,
#  'http://trapdatass.tumblr.com/': 2,
#  'http://www.worcester-online-news-magazine.co.uk/': 4,
#  'http://www.bagbyscrittercorral.com/': 1,
#  'http://giorgianolml.tumblr.com/': 3,
#  'http://www.csus.edu/': 15,
#  'https://www.cadbury.co.uk/': 3,
#  'http://www.freeradical.se/': 9,
#  'https://longmax5.wordpress.com/': 1,
#  'http://theopenscroll.com/': 2,
#  'http://charin553.blog75.fc2.com/': 7,
#  'https://secure.moddb.com/': 1,
#  'http://www.blindsuk.net/': 4,
#  'http://www.kitfort.ru/': 2,
#  'http://vallenatocanada.com/': 1,
#  'https://ads.twitter.com/': 1,
#  'http://parenting.blogs.nytimes.com/': 13,
#  'http://www.ifinpanorama.com/': 1,
#  'http://www.maruchan.com/': 1,
#  'http://mybringalong.tumblr.com/': 2,
#  'http://ural.kp.ru/': 1,
#  'http://www.coachoutletonlinecoachfactoryoutlet.us.com/': 1,
#  'http://lesduyfoh8.blog.fc2.com/': 2,
#  'http://malikhighs.tumblr.com/': 2,
#  'http://www.ojornalista.com/': 1,
#  'http://www.astonvillanews.com/': 351,
#  'http://ghjteokda2oadahaha.com/': 6,
#  'http://samer4zen.free.fr/': 4,
#  'http://libriscogitare.blogspot.com/': 2,
#  'http://eprints.bournemouth.ac.uk/': 1,
#  'http://www.noagendashow.com/': 1,
#  'http://hope-my-blog-doesnt-bother-you.tumblr.com/': 1,
#  'http://Coca-Cola\xc2\xa0Hellenic/': 1,
#  'http://www.friendshipmanor.org/': 2,
#  'http://www.thinksimple.de/': 2,
#  'http://tropicalcanadian.tumblr.com/': 2,
#  'http://www.redstonecontentsolutions.com/': 1,
#  'http://www.bernardgoldberg.com/': 2,
#  'http://ofalcaomaltes.blogspot.com/': 1,
#  'http://bookyourbook.lk/': 1,
#  'http://meduza.io/': 3,
#  'https://wilowforrestall.wordpress.com/': 1,
#  'http://www.ece.cmu.edu/': 1,
#  'http://the-erogazou.com/': 159,
#  'http://ofag6ezxpqr2jmozzi.usercash.com/': 1,
#  'http://ageoa11.blog.so-net.ne.jp/': 1,
#  'http://www.magnachip.com/': 1,
#  ...}

# %%
import operator
TopDomainCounts = list(sorted(DomainCounts.iteritems(), key=operator.itemgetter(1), reverse=True)[:1000])

# %%
DomainCounts['dailynews.com']
# Out:
# 344

# %%
top_news_sources = ['abcnews.go.com', 'cbsnews.com', 'cnn.com', 'foxnews.com', 'msnbc.com', 'nytimes.com', 'latimes.com',\
                   'usatoday.com', 'wsj.com', 'washingtonpost.com', 'bloomberg.com', 'vice.com', 'huffingtonpost.com', 'npr.org']

# %%
len(top_news_sources)
# Out:
# 14

# %%
conservative = ['foxnews.com', 'washingtonpost.com', 'theguardian.com', 'nypost.com', 'bloomberg.com', '']
liberal = ['nytimes.com', 'theatlantic.com', 'washingtonpost.com', 'huffingtonpost.com', 'vice.com', 'sfgate.com', '']
neutral = ['usatoday.com', 'cnn.com', 'bbc.com']

# %%
def printNeighborsAtHop(url, hops):
    node_id = domainToNodeID[url]
    NodeVec = snap.TIntV()
    snap.GetNodesAtHop(LinkGraph, node_id, hops, NodeVec, True)
    print NodeVec.Len()
    for item in NodeVec:
        domain = IDtoDomain[item]
        if domain in TopDomains:
            print domain

# %%
start_id = domainToNodeID["foxnews.com"]
results = []

for news_source in top_news_sources: 
    node_id = domainToNodeID[news_source]
    Length = snap.GetShortPath(LinkGraph, start_id, node_id)
    results.append((news_source, Length))
print results
# Out:
# [('abcnews.go.com', 2), ('cbsnews.com', 1), ('cnn.com', 1), ('foxnews.com', 0), ('msnbc.com', 2), ('nytimes.com', 1), ('latimes.com', 1), ('usatoday.com', 1), ('wsj.com', 1), ('washingtonpost.com', 1), ('bloomberg.com', 1), ('vice.com', 2), ('huffingtonpost.com', 1), ('npr.org', 2)]

# %%
start_id = domainToNodeID["nytimes.com"]
results = []

for news_source in top_news_sources: 
    node_id = domainToNodeID[news_source]
    Length = snap.GetShortPath(LinkGraph, start_id, node_id)
    results.append((news_source, Length))
print results
# Out:
# [('abcnews.go.com', 1), ('cbsnews.com', 1), ('cnn.com', 1), ('foxnews.com', 1), ('msnbc.com', 1), ('nytimes.com', 0), ('latimes.com', 1), ('usatoday.com', 1), ('wsj.com', 1), ('washingtonpost.com', 1), ('bloomberg.com', 1), ('vice.com', 1), ('huffingtonpost.com', 1), ('npr.org', 1)]

# %%
farthest_distance = -1
max_pair = ()
results = []

for news_source1 in top_news_sources:
    for news_source2 in top_news_sources: 
        if news_source1==news_source2:
            continue
        node_id1 = domainToNodeID[news_source1]
        node_id2 = domainToNodeID[news_source2]
        Length1 = snap.GetShortPath(LinkGraph, node_id1, node_id2)
        Length2 = snap.GetShortPath(LinkGraph, node_id2, node_id1)
        distance = max(Length1, Length2)
        results.append(((news_source1, news_source2), distance))

# %%
count = 0
for i in range(14):
    count += i
print count
# Out:
# 91

# %%
count1 = 0
count2 = 0
count3 = 0

for result in results:
    if result[1] == 1:
        count1 += 1
    elif result[1] == 2:
        count2 += 1
    else:
        count3 += 1

# %%
results
# Out:
# [(('abcnews.go.com', 'cbsnews.com'), 2),
#  (('abcnews.go.com', 'cnn.com'), 1),
#  (('abcnews.go.com', 'foxnews.com'), 2),
#  (('abcnews.go.com', 'msnbc.com'), 2),
#  (('abcnews.go.com', 'nytimes.com'), 1),
#  (('abcnews.go.com', 'latimes.com'), 2),
#  (('abcnews.go.com', 'usatoday.com'), 1),
#  (('abcnews.go.com', 'wsj.com'), 2),
#  (('abcnews.go.com', 'washingtonpost.com'), 1),
#  (('abcnews.go.com', 'bloomberg.com'), 2),
#  (('abcnews.go.com', 'vice.com'), 2),
#  (('abcnews.go.com', 'huffingtonpost.com'), 1),
#  (('abcnews.go.com', 'npr.org'), 1),
#  (('cbsnews.com', 'abcnews.go.com'), 2),
#  (('cbsnews.com', 'cnn.com'), 1),
#  (('cbsnews.com', 'foxnews.com'), 1),
#  (('cbsnews.com', 'msnbc.com'), 2),
#  (('cbsnews.com', 'nytimes.com'), 1),
#  (('cbsnews.com', 'latimes.com'), 1),
#  (('cbsnews.com', 'usatoday.com'), 1),
#  (('cbsnews.com', 'wsj.com'), 1),
#  (('cbsnews.com', 'washingtonpost.com'), 1),
#  (('cbsnews.com', 'bloomberg.com'), 2),
#  (('cbsnews.com', 'vice.com'), 2),
#  (('cbsnews.com', 'huffingtonpost.com'), 1),
#  (('cbsnews.com', 'npr.org'), 1),
#  (('cnn.com', 'abcnews.go.com'), 1),
#  (('cnn.com', 'cbsnews.com'), 1),
#  (('cnn.com', 'foxnews.com'), 1),
#  (('cnn.com', 'msnbc.com'), 1),
#  (('cnn.com', 'nytimes.com'), 1),
#  (('cnn.com', 'latimes.com'), 1),
#  (('cnn.com', 'usatoday.com'), 1),
#  (('cnn.com', 'wsj.com'), 1),
#  (('cnn.com', 'washingtonpost.com'), 1),
#  (('cnn.com', 'bloomberg.com'), 1),
#  (('cnn.com', 'vice.com'), 1),
#  (('cnn.com', 'huffingtonpost.com'), 1),
#  (('cnn.com', 'npr.org'), 1),
#  (('foxnews.com', 'abcnews.go.com'), 2),
#  (('foxnews.com', 'cbsnews.com'), 1),
#  (('foxnews.com', 'cnn.com'), 1),
#  (('foxnews.com', 'msnbc.com'), 2),
#  (('foxnews.com', 'nytimes.com'), 1),
#  (('foxnews.com', 'latimes.com'), 1),
#  (('foxnews.com', 'usatoday.com'), 1),
#  (('foxnews.com', 'wsj.com'), 1),
#  (('foxnews.com', 'washingtonpost.com'), 1),
#  (('foxnews.com', 'bloomberg.com'), 1),
#  (('foxnews.com', 'vice.com'), 2),
#  (('foxnews.com', 'huffingtonpost.com'), 1),
#  (('foxnews.com', 'npr.org'), 2),
#  (('msnbc.com', 'abcnews.go.com'), 2),
#  (('msnbc.com', 'cbsnews.com'), 2),
#  (('msnbc.com', 'cnn.com'), 1),
#  (('msnbc.com', 'foxnews.com'), 2),
#  (('msnbc.com', 'nytimes.com'), 1),
#  (('msnbc.com', 'latimes.com'), 2),
#  (('msnbc.com', 'usatoday.com'), 1),
#  (('msnbc.com', 'wsj.com'), 1),
#  (('msnbc.com', 'washingtonpost.com'), 1),
#  (('msnbc.com', 'bloomberg.com'), 2),
#  (('msnbc.com', 'vice.com'), 2),
#  (('msnbc.com', 'huffingtonpost.com'), 1),
#  (('msnbc.com', 'npr.org'), 1),
#  (('nytimes.com', 'abcnews.go.com'), 1),
#  (('nytimes.com', 'cbsnews.com'), 1),
#  (('nytimes.com', 'cnn.com'), 1),
#  (('nytimes.com', 'foxnews.com'), 1),
#  (('nytimes.com', 'msnbc.com'), 1),
#  (('nytimes.com', 'latimes.com'), 1),
#  (('nytimes.com', 'usatoday.com'), 1),
#  (('nytimes.com', 'wsj.com'), 1),
#  (('nytimes.com', 'washingtonpost.com'), 1),
#  (('nytimes.com', 'bloomberg.com'), 1),
#  (('nytimes.com', 'vice.com'), 1),
#  (('nytimes.com', 'huffingtonpost.com'), 1),
#  (('nytimes.com', 'npr.org'), 1),
#  (('latimes.com', 'abcnews.go.com'), 2),
#  (('latimes.com', 'cbsnews.com'), 1),
#  (('latimes.com', 'cnn.com'), 1),
#  (('latimes.com', 'foxnews.com'), 1),
#  (('latimes.com', 'msnbc.com'), 2),
#  (('latimes.com', 'nytimes.com'), 1),
#  (('latimes.com', 'usatoday.com'), 2),
#  (('latimes.com', 'wsj.com'), 2),
#  (('latimes.com', 'washingtonpost.com'), 1),
#  (('latimes.com', 'bloomberg.com'), 1),
#  (('latimes.com', 'vice.com'), 1),
#  (('latimes.com', 'huffingtonpost.com'), 1),
#  (('latimes.com', 'npr.org'), 1),
#  (('usatoday.com', 'abcnews.go.com'), 1),
#  (('usatoday.com', 'cbsnews.com'), 1),
#  (('usatoday.com', 'cnn.com'), 1),
#  (('usatoday.com', 'foxnews.com'), 1),
#  (('usatoday.com', 'msnbc.com'), 1),
#  (('usatoday.com', 'nytimes.com'), 1),
#  (('usatoday.com', 'latimes.com'), 2),
#  (('usatoday.com', 'wsj.com'), 1),
#  (('usatoday.com', 'washingtonpost.com'), 1),
#  (('usatoday.com', 'bloomberg.com'), 1),
#  (('usatoday.com', 'vice.com'), 1),
#  (('usatoday.com', 'huffingtonpost.com'), 1),
#  (('usatoday.com', 'npr.org'), 1),
#  (('wsj.com', 'abcnews.go.com'), 2),
#  (('wsj.com', 'cbsnews.com'), 1),
#  (('wsj.com', 'cnn.com'), 1),
#  (('wsj.com', 'foxnews.com'), 1),
#  (('wsj.com', 'msnbc.com'), 1),
#  (('wsj.com', 'nytimes.com'), 1),
#  (('wsj.com', 'latimes.com'), 2),
#  (('wsj.com', 'usatoday.com'), 1),
#  (('wsj.com', 'washingtonpost.com'), 1),
#  (('wsj.com', 'bloomberg.com'), 2),
#  (('wsj.com', 'vice.com'), 1),
#  (('wsj.com', 'huffingtonpost.com'), 1),
#  (('wsj.com', 'npr.org'), 2),
#  (('washingtonpost.com', 'abcnews.go.com'), 1),
#  (('washingtonpost.com', 'cbsnews.com'), 1),
#  (('washingtonpost.com', 'cnn.com'), 1),
#  (('washingtonpost.com', 'foxnews.com'), 1),
#  (('washingtonpost.com', 'msnbc.com'), 1),
#  (('washingtonpost.com', 'nytimes.com'), 1),
#  (('washingtonpost.com', 'latimes.com'), 1),
#  (('washingtonpost.com', 'usatoday.com'), 1),
#  (('washingtonpost.com', 'wsj.com'), 1),
#  (('washingtonpost.com', 'bloomberg.com'), 1),
#  (('washingtonpost.com', 'vice.com'), 1),
#  (('washingtonpost.com', 'huffingtonpost.com'), 1),
#  (('washingtonpost.com', 'npr.org'), 1),
#  (('bloomberg.com', 'abcnews.go.com'), 2),
#  (('bloomberg.com', 'cbsnews.com'), 2),
#  (('bloomberg.com', 'cnn.com'), 1),
#  (('bloomberg.com', 'foxnews.com'), 1),
#  (('bloomberg.com', 'msnbc.com'), 2),
#  (('bloomberg.com', 'nytimes.com'), 1),
#  (('bloomberg.com', 'latimes.com'), 1),
#  (('bloomberg.com', 'usatoday.com'), 1),
#  (('bloomberg.com', 'wsj.com'), 2),
#  (('bloomberg.com', 'washingtonpost.com'), 1),
#  (('bloomberg.com', 'vice.com'), 1),
#  (('bloomberg.com', 'huffingtonpost.com'), 1),
#  (('bloomberg.com', 'npr.org'), 1),
#  (('vice.com', 'abcnews.go.com'), 2),
#  (('vice.com', 'cbsnews.com'), 2),
#  (('vice.com', 'cnn.com'), 1),
#  (('vice.com', 'foxnews.com'), 2),
#  (('vice.com', 'msnbc.com'), 2),
#  (('vice.com', 'nytimes.com'), 1),
#  (('vice.com', 'latimes.com'), 1),
#  (('vice.com', 'usatoday.com'), 1),
#  (('vice.com', 'wsj.com'), 1),
#  (('vice.com', 'washingtonpost.com'), 1),
#  (('vice.com', 'bloomberg.com'), 1),
#  (('vice.com', 'huffingtonpost.com'), 1),
#  (('vice.com', 'npr.org'), 2),
#  (('huffingtonpost.com', 'abcnews.go.com'), 1),
#  (('huffingtonpost.com', 'cbsnews.com'), 1),
#  (('huffingtonpost.com', 'cnn.com'), 1),
#  (('huffingtonpost.com', 'foxnews.com'), 1),
#  (('huffingtonpost.com', 'msnbc.com'), 1),
#  (('huffingtonpost.com', 'nytimes.com'), 1),
#  (('huffingtonpost.com', 'latimes.com'), 1),
#  (('huffingtonpost.com', 'usatoday.com'), 1),
#  (('huffingtonpost.com', 'wsj.com'), 1),
#  (('huffingtonpost.com', 'washingtonpost.com'), 1),
#  (('huffingtonpost.com', 'bloomberg.com'), 1),
#  (('huffingtonpost.com', 'vice.com'), 1),
#  (('huffingtonpost.com', 'npr.org'), 1),
#  (('npr.org', 'abcnews.go.com'), 1),
#  (('npr.org', 'cbsnews.com'), 1),
#  (('npr.org', 'cnn.com'), 1),
#  (('npr.org', 'foxnews.com'), 2),
#  (('npr.org', 'msnbc.com'), 1),
#  (('npr.org', 'nytimes.com'), 1),
#  (('npr.org', 'latimes.com'), 1),
#  (('npr.org', 'usatoday.com'), 1),
#  (('npr.org', 'wsj.com'), 2),
#  (('npr.org', 'washingtonpost.com'), 1),
#  (('npr.org', 'bloomberg.com'), 1),
#  (('npr.org', 'vice.com'), 2),
#  (('npr.org', 'huffingtonpost.com'), 1)]

# %%
farthest_distance = -1
max_pair = ()
common_neighbors = []

for news_source1 in top_news_sources:
    for news_source2 in top_news_sources: 
        if news_source1 == news_source2:
            continue
        node_id1 = domainToNodeID[news_source1]
        node_id2 = domainToNodeID[news_source2]
        Nbrs = snap.TIntV()
        snap.GetCmnNbrs(LinkGraph, node_id1, node_id2, Nbrs)
        
        distance = Nbrs.Len()
        
        NodeVec = snap.TIntV()
        snap.GetNodesAtHop(LinkGraph, node_id1, 1, NodeVec, False)
        count1 = NodeVec.Len() 
        NodeVec = snap.TIntV()
        snap.GetNodesAtHop(LinkGraph, node_id2, 1, NodeVec, False)
        count2 = NodeVec.Len()
        denominator = min(count1, count2)        
        common_neighbors.append(((news_source1, news_source2), distance/float(denominator)))

# %%
common_neighbors
# Out:
# [(('abcnews.go.com', 'cbsnews.com'), 0.3514644351464435),
#  (('abcnews.go.com', 'cnn.com'), 0.4726962457337884),
#  (('abcnews.go.com', 'foxnews.com'), 0.2883959044368601),
#  (('abcnews.go.com', 'msnbc.com'), 0.4117647058823529),
#  (('abcnews.go.com', 'nytimes.com'), 0.5665529010238908),
#  (('abcnews.go.com', 'latimes.com'), 0.31399317406143346),
#  (('abcnews.go.com', 'usatoday.com'), 0.3703071672354949),
#  (('abcnews.go.com', 'wsj.com'), 0.3447098976109215),
#  (('abcnews.go.com', 'washingtonpost.com'), 0.5546075085324232),
#  (('abcnews.go.com', 'bloomberg.com'), 0.30204778156996587),
#  (('abcnews.go.com', 'vice.com'), 0.18592964824120603),
#  (('abcnews.go.com', 'huffingtonpost.com'), 0.40955631399317405),
#  (('abcnews.go.com', 'npr.org'), 0.27474402730375425),
#  (('cbsnews.com', 'abcnews.go.com'), 0.3514644351464435),
#  (('cbsnews.com', 'cnn.com'), 0.4560669456066946),
#  (('cbsnews.com', 'foxnews.com'), 0.29916317991631797),
#  (('cbsnews.com', 'msnbc.com'), 0.36764705882352944),
#  (('cbsnews.com', 'nytimes.com'), 0.5774058577405857),
#  (('cbsnews.com', 'latimes.com'), 0.3179916317991632),
#  (('cbsnews.com', 'usatoday.com'), 0.39330543933054396),
#  (('cbsnews.com', 'wsj.com'), 0.34518828451882844),
#  (('cbsnews.com', 'washingtonpost.com'), 0.5271966527196653),
#  (('cbsnews.com', 'bloomberg.com'), 0.3158995815899582),
#  (('cbsnews.com', 'vice.com'), 0.19597989949748743),
#  (('cbsnews.com', 'huffingtonpost.com'), 0.41631799163179917),
#  (('cbsnews.com', 'npr.org'), 0.2824267782426778),
#  (('cnn.com', 'abcnews.go.com'), 0.4726962457337884),
#  (('cnn.com', 'cbsnews.com'), 0.4560669456066946),
#  (('cnn.com', 'foxnews.com'), 0.3294964028776978),
#  (('cnn.com', 'msnbc.com'), 0.5220588235294118),
#  (('cnn.com', 'nytimes.com'), 0.5043936731107206),
#  (('cnn.com', 'latimes.com'), 0.33292831105710813),
#  (('cnn.com', 'usatoday.com'), 0.3673469387755102),
#  (('cnn.com', 'wsj.com'), 0.3090507726269316),
#  (('cnn.com', 'washingtonpost.com'), 0.4806678383128295),
#  (('cnn.com', 'bloomberg.com'), 0.2958380202474691),
#  (('cnn.com', 'vice.com'), 0.2964824120603015),
#  (('cnn.com', 'huffingtonpost.com'), 0.3189806678383128),
#  (('cnn.com', 'npr.org'), 0.26632653061224487),
#  (('foxnews.com', 'abcnews.go.com'), 0.2883959044368601),
#  (('foxnews.com', 'cbsnews.com'), 0.29916317991631797),
#  (('foxnews.com', 'cnn.com'), 0.3294964028776978),
#  (('foxnews.com', 'msnbc.com'), 0.375),
#  (('foxnews.com', 'nytimes.com'), 0.4273381294964029),
#  (('foxnews.com', 'latimes.com'), 0.22877697841726619),
#  (('foxnews.com', 'usatoday.com'), 0.2489208633093525),
#  (('foxnews.com', 'wsj.com'), 0.27050359712230215),
#  (('foxnews.com', 'washingtonpost.com'), 0.40863309352517985),
#  (('foxnews.com', 'bloomberg.com'), 0.22589928057553957),
#  (('foxnews.com', 'vice.com'), 0.23115577889447236),
#  (('foxnews.com', 'huffingtonpost.com'), 0.33237410071942447),
#  (('foxnews.com', 'npr.org'), 0.218705035971223),
#  (('msnbc.com', 'abcnews.go.com'), 0.4117647058823529),
#  (('msnbc.com', 'cbsnews.com'), 0.36764705882352944),
#  (('msnbc.com', 'cnn.com'), 0.5220588235294118),
#  (('msnbc.com', 'foxnews.com'), 0.375),
#  (('msnbc.com', 'nytimes.com'), 0.6985294117647058),
#  (('msnbc.com', 'latimes.com'), 0.4411764705882353),
#  (('msnbc.com', 'usatoday.com'), 0.4485294117647059),
#  (('msnbc.com', 'wsj.com'), 0.36764705882352944),
#  (('msnbc.com', 'washingtonpost.com'), 0.6029411764705882),
#  (('msnbc.com', 'bloomberg.com'), 0.4411764705882353),
#  (('msnbc.com', 'vice.com'), 0.1323529411764706),
#  (('msnbc.com', 'huffingtonpost.com'), 0.6176470588235294),
#  (('msnbc.com', 'npr.org'), 0.4632352941176471),
#  (('nytimes.com', 'abcnews.go.com'), 0.5665529010238908),
#  (('nytimes.com', 'cbsnews.com'), 0.5774058577405857),
#  (('nytimes.com', 'cnn.com'), 0.5043936731107206),
#  (('nytimes.com', 'foxnews.com'), 0.4273381294964029),
#  (('nytimes.com', 'msnbc.com'), 0.6985294117647058),
#  (('nytimes.com', 'latimes.com'), 0.4787363304981774),
#  (('nytimes.com', 'usatoday.com'), 0.4954648526077097),
#  (('nytimes.com', 'wsj.com'), 0.5275938189845475),
#  (('nytimes.com', 'washingtonpost.com'), 0.43922369765066394),
#  (('nytimes.com', 'bloomberg.com'), 0.45219347581552305),
#  (('nytimes.com', 'vice.com'), 0.3869346733668342),
#  (('nytimes.com', 'huffingtonpost.com'), 0.28705533596837945),
#  (('nytimes.com', 'npr.org'), 0.42857142857142855),
#  (('latimes.com', 'abcnews.go.com'), 0.31399317406143346),
#  (('latimes.com', 'cbsnews.com'), 0.3179916317991632),
#  (('latimes.com', 'cnn.com'), 0.33292831105710813),
#  (('latimes.com', 'foxnews.com'), 0.22877697841726619),
#  (('latimes.com', 'msnbc.com'), 0.4411764705882353),
#  (('latimes.com', 'nytimes.com'), 0.4787363304981774),
#  (('latimes.com', 'usatoday.com'), 0.275820170109356),
#  (('latimes.com', 'wsj.com'), 0.29040097205346294),
#  (('latimes.com', 'washingtonpost.com'), 0.4374240583232078),
#  (('latimes.com', 'bloomberg.com'), 0.23815309842041313),
#  (('latimes.com', 'vice.com'), 0.22613065326633167),
#  (('latimes.com', 'huffingtonpost.com'), 0.33171324422843257),
#  (('latimes.com', 'npr.org'), 0.25759416767922233),
#  (('usatoday.com', 'abcnews.go.com'), 0.3703071672354949),
#  (('usatoday.com', 'cbsnews.com'), 0.39330543933054396),
#  (('usatoday.com', 'cnn.com'), 0.3673469387755102),
#  (('usatoday.com', 'foxnews.com'), 0.2489208633093525),
#  (('usatoday.com', 'msnbc.com'), 0.4485294117647059),
#  (('usatoday.com', 'nytimes.com'), 0.4954648526077097),
#  (('usatoday.com', 'latimes.com'), 0.275820170109356),
#  (('usatoday.com', 'wsj.com'), 0.29591836734693877),
#  (('usatoday.com', 'washingtonpost.com'), 0.445578231292517),
#  (('usatoday.com', 'bloomberg.com'), 0.2585034013605442),
#  (('usatoday.com', 'vice.com'), 0.23618090452261306),
#  (('usatoday.com', 'huffingtonpost.com'), 0.31859410430839),
#  (('usatoday.com', 'npr.org'), 0.2256235827664399),
#  (('wsj.com', 'abcnews.go.com'), 0.3447098976109215),
#  (('wsj.com', 'cbsnews.com'), 0.34518828451882844),
#  (('wsj.com', 'cnn.com'), 0.3090507726269316),
#  (('wsj.com', 'foxnews.com'), 0.27050359712230215),
#  (('wsj.com', 'msnbc.com'), 0.36764705882352944),
#  (('wsj.com', 'nytimes.com'), 0.5275938189845475),
#  (('wsj.com', 'latimes.com'), 0.29040097205346294),
#  (('wsj.com', 'usatoday.com'), 0.29591836734693877),
#  (('wsj.com', 'washingtonpost.com'), 0.45253863134657835),
#  (('wsj.com', 'bloomberg.com'), 0.35883014623172105),
#  (('wsj.com', 'vice.com'), 0.2562814070351759),
#  (('wsj.com', 'huffingtonpost.com'), 0.31015452538631344),
#  (('wsj.com', 'npr.org'), 0.2306843267108168),
#  (('washingtonpost.com', 'abcnews.go.com'), 0.5546075085324232),
#  (('washingtonpost.com', 'cbsnews.com'), 0.5271966527196653),
#  (('washingtonpost.com', 'cnn.com'), 0.4806678383128295),
#  (('washingtonpost.com', 'foxnews.com'), 0.40863309352517985),
#  (('washingtonpost.com', 'msnbc.com'), 0.6029411764705882),
#  (('washingtonpost.com', 'nytimes.com'), 0.43922369765066394),
#  (('washingtonpost.com', 'latimes.com'), 0.4374240583232078),
#  (('washingtonpost.com', 'usatoday.com'), 0.445578231292517),
#  (('washingtonpost.com', 'wsj.com'), 0.45253863134657835),
#  (('washingtonpost.com', 'bloomberg.com'), 0.4026996625421822),
#  (('washingtonpost.com', 'vice.com'), 0.39195979899497485),
#  (('washingtonpost.com', 'huffingtonpost.com'), 0.2676200204290092),
#  (('washingtonpost.com', 'npr.org'), 0.3816326530612245),
#  (('bloomberg.com', 'abcnews.go.com'), 0.30204778156996587),
#  (('bloomberg.com', 'cbsnews.com'), 0.3158995815899582),
#  (('bloomberg.com', 'cnn.com'), 0.2958380202474691),
#  (('bloomberg.com', 'foxnews.com'), 0.22589928057553957),
#  (('bloomberg.com', 'msnbc.com'), 0.4411764705882353),
#  (('bloomberg.com', 'nytimes.com'), 0.45219347581552305),
#  (('bloomberg.com', 'latimes.com'), 0.23815309842041313),
#  (('bloomberg.com', 'usatoday.com'), 0.2585034013605442),
#  (('bloomberg.com', 'wsj.com'), 0.35883014623172105),
#  (('bloomberg.com', 'washingtonpost.com'), 0.4026996625421822),
#  (('bloomberg.com', 'vice.com'), 0.19597989949748743),
#  (('bloomberg.com', 'huffingtonpost.com'), 0.2722159730033746),
#  (('bloomberg.com', 'npr.org'), 0.20584926884139482),
#  (('vice.com', 'abcnews.go.com'), 0.18592964824120603),
#  (('vice.com', 'cbsnews.com'), 0.19597989949748743),
#  (('vice.com', 'cnn.com'), 0.2964824120603015),
#  (('vice.com', 'foxnews.com'), 0.23115577889447236),
#  (('vice.com', 'msnbc.com'), 0.1323529411764706),
#  (('vice.com', 'nytimes.com'), 0.3869346733668342),
#  (('vice.com', 'latimes.com'), 0.22613065326633167),
#  (('vice.com', 'usatoday.com'), 0.23618090452261306),
#  (('vice.com', 'wsj.com'), 0.2562814070351759),
#  (('vice.com', 'washingtonpost.com'), 0.39195979899497485),
#  (('vice.com', 'bloomberg.com'), 0.19597989949748743),
#  (('vice.com', 'huffingtonpost.com'), 0.3768844221105528),
#  (('vice.com', 'npr.org'), 0.2663316582914573),
#  (('huffingtonpost.com', 'abcnews.go.com'), 0.40955631399317405),
#  (('huffingtonpost.com', 'cbsnews.com'), 0.41631799163179917),
#  (('huffingtonpost.com', 'cnn.com'), 0.3189806678383128),
#  (('huffingtonpost.com', 'foxnews.com'), 0.33237410071942447),
#  (('huffingtonpost.com', 'msnbc.com'), 0.6176470588235294),
#  (('huffingtonpost.com', 'nytimes.com'), 0.28705533596837945),
#  (('huffingtonpost.com', 'latimes.com'), 0.33171324422843257),
#  (('huffingtonpost.com', 'usatoday.com'), 0.31859410430839),
#  (('huffingtonpost.com', 'wsj.com'), 0.31015452538631344),
#  (('huffingtonpost.com', 'washingtonpost.com'), 0.2676200204290092),
#  (('huffingtonpost.com', 'bloomberg.com'), 0.2722159730033746),
#  (('huffingtonpost.com', 'vice.com'), 0.3768844221105528),
#  (('huffingtonpost.com', 'npr.org'), 0.2979591836734694),
#  (('npr.org', 'abcnews.go.com'), 0.27474402730375425),
#  (('npr.org', 'cbsnews.com'), 0.2824267782426778),
#  (('npr.org', 'cnn.com'), 0.26632653061224487),
#  (('npr.org', 'foxnews.com'), 0.218705035971223),
#  (('npr.org', 'msnbc.com'), 0.4632352941176471),
#  (('npr.org', 'nytimes.com'), 0.42857142857142855),
#  (('npr.org', 'latimes.com'), 0.25759416767922233),
#  (('npr.org', 'usatoday.com'), 0.2256235827664399),
#  (('npr.org', 'wsj.com'), 0.2306843267108168),
#  (('npr.org', 'washingtonpost.com'), 0.3816326530612245),
#  (('npr.org', 'bloomberg.com'), 0.20584926884139482),
#  (('npr.org', 'vice.com'), 0.2663316582914573),
#  (('npr.org', 'huffingtonpost.com'), 0.2979591836734694)]

# %%
from operator import itemgetter

print max(common_neighbors,key=itemgetter(1))
print min(common_neighbors,key=itemgetter(1))
# Out:
# (('msnbc.com', 'nytimes.com'), 0.6985294117647058)
# (('msnbc.com', 'vice.com'), 0.1323529411764706)

# %%
farthest_distance = -1
max_pair = ()
common_neighbors = []

for news_source1 in top_news_sources:
    for news_source2 in top_news_sources: 
        if news_source1 == news_source2:
            continue
        node_id1 = domainToNodeID[news_source1]
        node_id2 = domainToNodeID[news_source2]
        
        NodeVec1 = snap.TIntV()
        snap.GetNodesAtHop(LinkGraph, node_id1, 2, NodeVec1, False)
        count1 = NodeVec1.Len() 
        
        NodeVec2 = snap.TIntV()
        snap.GetNodesAtHop(LinkGraph, node_id2, 2, NodeVec2, False)
        count2 = NodeVec2.Len()
        
        nodes_1 = []
        nodes_2 = []
        for item in NodeVec1:
            nodes_1.append(item)
        for item in NodeVec2: 
            nodes_2.append(item)
            
        intersection = len(list(set(nodes_1) & set(nodes_2)))
        
        denominator = min(len(nodes_1), len(nodes_2))        
        common_neighbors.append(((news_source1, news_source2), intersection/float(denominator)))

# %%
print max(common_neighbors,key=itemgetter(1))
print min(common_neighbors,key=itemgetter(1))
# Out:
# (('msnbc.com', 'latimes.com'), 0.9641341980787048)
# (('wsj.com', 'npr.org'), 0.7527530641448392)

# %%
common_neighbors = sorted(common_neighbors, key=itemgetter(1), reverse=True)
for result in common_neighbors:
    if result[0][1] == 'nytimes.com': 
        print result
# Out:
# (('msnbc.com', 'nytimes.com'), 0.9328278148924758)
# (('cbsnews.com', 'nytimes.com'), 0.9288963860348617)
# (('cnn.com', 'nytimes.com'), 0.92171736798744)
# (('abcnews.go.com', 'nytimes.com'), 0.9216555022240976)
# (('vice.com', 'nytimes.com'), 0.9144191426918875)
# (('npr.org', 'nytimes.com'), 0.9087911404218254)
# (('foxnews.com', 'nytimes.com'), 0.8958316457951949)
# (('latimes.com', 'nytimes.com'), 0.8868552903035661)
# (('wsj.com', 'nytimes.com'), 0.8832681391723772)
# (('usatoday.com', 'nytimes.com'), 0.8777611856192945)
# (('bloomberg.com', 'nytimes.com'), 0.8694601469756925)
# (('washingtonpost.com', 'nytimes.com'), 0.8577147445738174)
# (('huffingtonpost.com', 'nytimes.com'), 0.8434992079389393)

# %%
for result in common_neighbors:
    if result[0][1] == 'foxnews.com': 
        print result
# Out:
# (('npr.org', 'foxnews.com'), 0.7932347271048326)
# (('latimes.com', 'foxnews.com'), 0.8052229980397557)
# (('cnn.com', 'foxnews.com'), 0.813501385131304)
# (('huffingtonpost.com', 'foxnews.com'), 0.8171950686085505)
# (('wsj.com', 'foxnews.com'), 0.8183614949697863)
# (('abcnews.go.com', 'foxnews.com'), 0.8360321395291594)
# (('cbsnews.com', 'foxnews.com'), 0.8437526623387688)
# (('usatoday.com', 'foxnews.com'), 0.8507136261279505)
# (('bloomberg.com', 'foxnews.com'), 0.8537268942278096)
# (('nytimes.com', 'foxnews.com'), 0.8958316457951949)
# (('washingtonpost.com', 'foxnews.com'), 0.9007403567320621)
# (('vice.com', 'foxnews.com'), 0.9025085152417471)
# (('msnbc.com', 'foxnews.com'), 0.9306578241576047)

# %%
keys = IDtoDomain.keys()

key_list = []

for i in range(len(keys)):
    for j in range(i + 1, len(keys)): 
        node_1 = keys[i]
        node_2 = keys[j]
        Length1 = snap.GetShortPath(LinkGraph, node_1, node_2)
        Length2 = snap.GetShortPath(LinkGraph, node_2, node_1)
        min_length = min(Length1, Length2)
        max_length = max(Length1, Length2)
        key_list.append( ((node_1, node_2), min_length, max_length))
